# %%
import os
import cv2
import numpy as np
from tqdm import tqdm
import pandas as pd


DATADIR = 'datta'
CATEGORIES = ['0', '1','2','3']
labelFile = 'labels.csv' # file with all names of classes




IMG_SIZE = 64
def create_training_data():
    training_data = []
    for category in CATEGORIES:  

        path = os.path.join(DATADIR,category) 
        class_num = CATEGORIES.index(category)  # get the classification  (0 or a 1). 0=C 1=O
        for img in tqdm(os.listdir(path)):  # iterate over each image
            try:
                img_array = cv2.imread(os.path.join(path,img))  # convert to array
                new_array = cv2.resize(img_array, (IMG_SIZE, IMG_SIZE)) # resize to normalize data size
                training_data.append([new_array, class_num])  # add this to our training_data
            except Exception as e:  # in the interest in keeping the output clean...
                pass
              
    return training_data

data=pd.read_csv(labelFile)
print("data shape ",data.shape,type(data))


training_data = create_training_data()


import random

print(len(training_data))
random.shuffle(training_data)
for sample in training_data[:10]:
    print(sample[1])


X = []
Y = []

for features,label in training_data:
    X.append(features)
    Y.append(label)

X = np.array(X).reshape(-1, IMG_SIZE, IMG_SIZE, 3)
X = X/255.0
X.shape[1:]

y=np.array(Y)
# Out:
# 100%|██████████| 200/200 [00:00<00:00, 4360.57it/s]
# 100%|██████████| 189/189 [00:00<00:00, 3786.16it/s]
#   0%|          | 0/176 [00:00<?, ?it/s]
# data shape  (4, 2) <class 'pandas.core.frame.DataFrame'>
# 100%|██████████| 176/176 [00:00<00:00, 316.79it/s]
# 100%|██████████| 177/177 [00:00<00:00, 453.22it/s]
# 739
# 3
# 3
# 1
# 3
# 1
# 0
# 0
# 2
# 2
# 2

# %%
import tensorflow as tf
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten
from tensorflow.keras.layers import Conv2D, AveragePooling2D
model = Sequential()


model.add(Conv2D(filters=16, kernel_size=(3, 3), activation='relu', input_shape=X.shape[1:]))
model.add(AveragePooling2D())
model.add(Dropout(0.5))

model.add(Conv2D(filters=32, kernel_size=(3, 3), activation='relu'))
model.add(AveragePooling2D())
model.add(Dropout(0.5))

model.add(Conv2D(filters=64, kernel_size=(3, 3), activation='relu'))
model.add(AveragePooling2D())
model.add(Dropout(0.5))

model.add(Flatten())

model.add(Dense(units=256, activation='relu'))
model.add(Dropout(0.2))

model.add(Dense(units=128, activation='relu'))

model.add(Dense(units=4, activation = 'softmax'))

model.compile(loss='sparse_categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])




history = model.fit(X, y, batch_size=32, epochs=50,validation_split=0.3)
model.save('modelsign2.h5')
# Out:
# Epoch 1/50
# 17/17 [==============================] - 5s 290ms/step - loss: 1.3653 - accuracy: 0.3017 - val_loss: 1.3199 - val_accuracy: 0.3784
# Epoch 2/50
# 17/17 [==============================] - 4s 262ms/step - loss: 1.2197 - accuracy: 0.4836 - val_loss: 0.9204 - val_accuracy: 0.7207
# Epoch 3/50
# 17/17 [==============================] - 4s 251ms/step - loss: 0.9731 - accuracy: 0.6093 - val_loss: 0.7312 - val_accuracy: 0.7928
# Epoch 4/50
# 17/17 [==============================] - 4s 241ms/step - loss: 0.7477 - accuracy: 0.7195 - val_loss: 0.5307 - val_accuracy: 0.7613
# Epoch 5/50
# 17/17 [==============================] - 4s 256ms/step - loss: 0.5789 - accuracy: 0.7737 - val_loss: 0.4813 - val_accuracy: 0.7568
# Epoch 6/50
# 17/17 [==============================] - 4s 262ms/step - loss: 0.4885 - accuracy: 0.7930 - val_loss: 0.4005 - val_accuracy: 0.8243
# Epoch 7/50
# 17/17 [==============================] - 4s 227ms/step - loss: 0.4316 - accuracy: 0.8027 - val_loss: 0.3673 - val_accuracy: 0.8198
# Epoch 8/50
# 17/17 [==============================] - 5s 267ms/step - loss: 0.3565 - accuracy: 0.8433 - val_loss: 0.3414 - val_accuracy: 0.8288
# Epoch 9/50
# 17/17 [==============================] - 4s 249ms/step - loss: 0.3840 - accuracy: 0.8221 - val_loss: 0.2635 - val_accuracy: 0.9369
# 17/17 [==============================] - 4s 247ms/step - loss: 0.0954 - accuracy: 0.9613 - val_loss: 0.0889 - val_accuracy: 0.9640
# Epoch 31/50
# 17/17 [==============================] - 5s 282ms/step - loss: 0.1281 - accuracy: 0.9439 - val_loss: 0.0797 - val_accuracy: 0.9685
# Epoch 32/50
# 17/17 [==============================] - 5s 265ms/step - loss: 0.1042 - accuracy: 0.9652 - val_loss: 0.0972 - val_accuracy: 0.9640
# Epoch 33/50
# 17/17 [==============================] - 5s 269ms/step - loss: 0.0882 - accuracy: 0.9632 - val_loss: 0.0483 - val_accuracy: 0.9820
# Epoch 34/50
# 17/17 [==============================] - 4s 259ms/step - loss: 0.0613 - accuracy: 0.9807 - val_loss: 0.0583 - val_accuracy: 0.9775
# Epoch 35/50
# 17/17 [==============================] - 5s 275ms/step - loss: 0.0573 - accuracy: 0.9729 - val_loss: 0.0677 - val_accuracy: 0.9775
# Epoch 36/50
# 17/17 [==============================] - 5s 286ms/step - loss: 0.0526 - accuracy: 0.9845 - val_loss: 0.1103 - val_accuracy: 0.9550
# Epoch 37/50
# 17/17 [==============================] - 4s 260ms/step - loss: 0.0617 - accuracy: 0.9749 - val_loss: 0.0801 - val_accuracy: 0.9730
# Epoch 38/50
# 17/17 [==============================] - 4s 261ms/step - loss: 0.0675 - accuracy: 0.9749 - val_loss: 0.0772 - val_accuracy: 0.9685
# Epoch 39/50
# 17/17 [==============================] - 4s 253ms/step - loss: 0.0755 - accuracy: 0.9632 - val_loss: 0.0985 - val_accuracy: 0.9685
# Epoch 40/50
# 17/17 [==============================] - 4s 245ms/step - loss: 0.0470 - accuracy: 0.9787 - val_loss: 0.0666 - val_accuracy: 0.9730
# Epoch 41/50
# 17/17 [==============================] - 5s 276ms/step - loss: 0.0600 - accuracy: 0.9845 - val_loss: 0.0738 - val_accuracy: 0.9640
# Epoch 42/50
# 17/17 [==============================] - 4s 256ms/step - loss: 0.0465 - accuracy: 0.9826 - val_loss: 0.0793 - val_accuracy: 0.9730
# Epoch 43/50
# 17/17 [==============================] - 4s 252ms/step - loss: 0.0327 - accuracy: 0.9865 - val_loss: 0.0688 - val_accuracy: 0.9685
# Epoch 44/50
# 17/17 [==============================] - 4s 257ms/step - loss: 0.0500 - accuracy: 0.9826 - val_loss: 0.1358 - val_accuracy: 0.9730
# Epoch 45/50
# 17/17 [==============================] - 5s 270ms/step - loss: 0.0336 - accuracy: 0.9845 - val_loss: 0.0604 - val_accuracy: 0.9775
# Epoch 46/50
# 17/17 [==============================] - 4s 251ms/step - loss: 0.0818 - accuracy: 0.9768 - val_loss: 0.1203 - val_accuracy: 0.9730
# Epoch 47/50
# 17/17 [==============================] - 4s 255ms/step - loss: 0.0350 - accuracy: 0.9903 - val_loss: 0.1050 - val_accuracy: 0.9730
# Epoch 48/50
# 17/17 [==============================] - 5s 278ms/step - loss: 0.0376 - accuracy: 0.9884 - val_loss: 0.0477 - val_accuracy: 0.9775
# Epoch 49/50
# 17/17 [==============================] - 4s 259ms/step - loss: 0.0333 - accuracy: 0.9884 - val_loss: 0.0789 - val_accuracy: 0.9775
# Epoch 50/50
# 17/17 [==============================] - 5s 304ms/step - loss: 0.0583 - accuracy: 0.9768 - val_loss: 0.0617 - val_accuracy: 0.9730
